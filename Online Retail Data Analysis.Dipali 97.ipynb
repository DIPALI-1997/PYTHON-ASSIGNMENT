# %% [markdown]
# # Online Retail Data Analysis
#
#    7 January 2024

# %%
#import all the necessary libraries 
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings("ignore")

# %%
#load a file
data=pd.read_csv("Online Retail.csv")

# %%
#make a copyu of data to perform analysis 
df=data.copy()

# %%
#cheack the data
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
#data shape
df.shape
# Out:
# (541909, 8)

# %%
#no of columns in  dataset
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
#information about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
#cheacking the null values
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %% [markdown]
# from the above ,there are null values in two columns i. e."Discription" and "CustomerID"

# %% [markdown]
# # Analysing the columns of the data one by one

# %% [markdown]
# Analysis of column "InvoiceNo"

# %%
#sample of the data
df.sample(5)
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 513964    579666     23202             JUMBO BAG VINTAGE LEAF        10
# 309161   C564063     71477  COLOUR GLASS. STAR T-LIGHT HOLDER        -1
# 317684    564817     20725            LUNCH BAG RED RETROSPOT         2
# 258109    559552    85024C     PINK SMALL JEWELLED PHOTOFRAME         1
# 280887    561507     21055                 TOOL BOX SOFT TOY          2
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 513964  11/30/11 12:31       2.08     14893.0  United Kingdom
# 309161   8/22/11 15:00       3.25     16184.0  United Kingdom
# 317684   8/30/11 12:02       4.13         NaN  United Kingdom
# 258109   7/10/11 16:29       1.65     16014.0  United Kingdom
# 280887   7/27/11 14:21       8.95     12397.0         Belgium

# %%
#going through respected columns step by step
df["InvoiceNo"]
# Out:
# 0         536365
# 1         536365
# 2         536365
# 3         536365
# 4         536365
#            ...
# 541904    581587
# 541905    581587
# 541906    581587
# 541907    581587
# 541908    581587
# Name: InvoiceNo, Length: 541909, dtype: object

# %%
#cheacking for unique value in given column
df["InvoiceNo"].unique()
# Out:
# array(['536365', '536366', '536367', ..., '581585', '581586', '581587'],
#       dtype=object)

# %%
len(df["InvoiceNo"].unique())
# Out:
# 25900

# %%
#copy the "InvoiceNo" column to compare
df["Invoice_copy"]=df["InvoiceNo"].copy()

# %%
#cheack the "InvoiceNo" column containing alphabet 'C'
df[data["InvoiceNo"].str.contains('C')]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#           InvoiceDate  UnitPrice  CustomerID         Country Invoice_copy
# ...

# %%
#replace the alphabet 'C' with space
df["InvoiceNo"]=df["InvoiceNo"].str.replace('C','')

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#           InvoiceDate  UnitPrice  CustomerID         Country Invoice_copy
# ...

# %%
#checking the filtered InvoiceNo with the Invoice_copy
df[df['Invoice_copy'].str.contains('C')]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141       536379         D                          Discount        -1
# 154       536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235       536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236       536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237       536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449    581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541    581499         M                            Manual        -1
# 541715    581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716    581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717    581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#           InvoiceDate  UnitPrice  CustomerID         Country Invoice_copy
# ...

# %% [markdown]
# Analysi of column 'InvoiceDate	'

# %%
#create a copy of the 'InvoiceDate	' column for compare
df["Date_copy"]=df["InvoiceDate"].copy()

# %%
#converting proper format of date
df["InvoiceDate"]=pd.to_datetime(df["InvoiceDate"]).dt.date

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#   InvoiceDate  UnitPrice  CustomerID         Country Invoice_copy
# 0  2010-12-01       2.55     17850.0  United Kingdom       536365
# 1  2010-12-01       3.39     17850.0  United Kingdom       536365
# 2  2010-12-01       2.75     17850.0  United Kingdom       536365
# 3  2010-12-01       3.39     17850.0  United Kingdom       536365
# 4  2010-12-01       3.39     17850.0  United Kingdom       536365

# %% [markdown]
# Analysis of column CustomerID""

# %%
#find a null values
data['CustomerID'].isnull().sum()
# Out:
# 0

# %%
#get the data with null values
df[df["CustomerID"].isnull()]
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 622       536414     22139                              NaN        56
# 1443      536544     21773  DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444      536544     21774  DECORATIVE CATS BATHROOM BOTTLE         2
# 1445      536544     21786               POLKADOT RAIN HAT          4
# 1446      536544     21787            RAIN PONCHO RETROSPOT         2
# ...          ...       ...                              ...       ...
# 541536    581498    85099B          JUMBO BAG RED RETROSPOT         5
# 541537    581498    85099C   JUMBO  BAG BAROQUE BLACK WHITE         4
# 541538    581498     85150    LADIES & GENTLEMEN METAL SIGN         1
# 541539    581498     85174                S/4 CACTI CANDLES         1
# 541540    581498       DOT                   DOTCOM POSTAGE         1
#
#        InvoiceDate  UnitPrice  CustomerID         Country Invoice_copy
# ...

# %%
#replacing the null values with 0
df["CustomerID"].fillna(0,inplace=True)

# %%
#cheack the data either null value replace or not in respected column
df[df["CustomerID"]==0]
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 622       536414     22139                              NaN        56
# 1443      536544     21773  DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444      536544     21774  DECORATIVE CATS BATHROOM BOTTLE         2
# 1445      536544     21786               POLKADOT RAIN HAT          4
# 1446      536544     21787            RAIN PONCHO RETROSPOT         2
# ...          ...       ...                              ...       ...
# 541536    581498    85099B          JUMBO BAG RED RETROSPOT         5
# 541537    581498    85099C   JUMBO  BAG BAROQUE BLACK WHITE         4
# 541538    581498     85150    LADIES & GENTLEMEN METAL SIGN         1
# 541539    581498     85174                S/4 CACTI CANDLES         1
# 541540    581498       DOT                   DOTCOM POSTAGE         1
#
#        InvoiceDate  UnitPrice  CustomerID         Country Invoice_copy
# ...

# %%
# checking the numbers of null values in it.
df["CustomerID"].isnull().sum()
# Out:
# 0

# %%
df.head(5)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#   InvoiceDate  UnitPrice  CustomerID         Country Invoice_copy
# 0  2010-12-01       2.55     17850.0  United Kingdom       536365
# 1  2010-12-01       3.39     17850.0  United Kingdom       536365
# 2  2010-12-01       2.75     17850.0  United Kingdom       536365
# 3  2010-12-01       3.39     17850.0  United Kingdom       536365
# 4  2010-12-01       3.39     17850.0  United Kingdom       536365

# %% [markdown]
# Analysis of column “Quantity”

# %%
#cheack the null values
df["Quantity"].isnull().sum()
# Out:
# 0

# %%
#cheack the unique values
df["Quantity"].unique()
# Out:
# array([     6,      8,      2,     32,      3,      4,     24,     12,
#            48,     18,     20,     36,     80,     64,     10,    120,
#            96,     23,      5,      1,     -1,     50,     40,    100,
#           192,    432,    144,    288,    -12,    -24,     16,      9,
#           128,     25,     30,     28,      7,     56,     72,    200,
#           600,    480,     -6,     14,     -2,     11,     33,     13,
#            -4,     -5,     -7,     -3,     70,    252,     60,    216,
#           384,    -10,     27,     15,     22,     19,     17,     21,
#            34,     47,    108,     52,  -9360,    -38,     75,    270,
#            42,    240,     90,    320,   1824,    204,     69,    -36,
#          -192,   -144,    160,   2880,   1400,     39,    -48,    -50,
#            26,   1440,     31,     82,     78,     97,     98,     35,
#            57,    -20,    110,    -22,    -30,    -70,   -130,    -80,
# ...

# %% [markdown]
# From the above output , there are many negative values...We have to replace by 0

# %%
df.loc[df["Quantity"]<0,'Quantity']=0

# %%
#check the negative values
data['Quantity'].unique()
# Out:
# array([    6,     8,     2,    32,     3,     4,    24,    12,    48,
#           18,    20,    36,    80,    64,    10,   120,    96,    23,
#            5,     1,     0,    50,    40,   100,   192,   432,   144,
#          288,    16,     9,   128,    25,    30,    28,     7,    56,
#           72,   200,   600,   480,    14,    11,    33,    13,    70,
#          252,    60,   216,   384,    27,    15,    22,    19,    17,
#           21,    34,    47,   108,    52,    75,   270,    42,   240,
#           90,   320,  1824,   204,    69,   160,  2880,  1400,    39,
#           26,  1440,    31,    82,    78,    97,    98,    35,    57,
#          110,   720,   156,   324,    38,    37,    49,    95,    29,
#           41,   402,   378,   150,   300,    54,   104,    67,   258,
#           66,    44,    55,    46,    99,    61,   408,   972,   208,
#         1008,  1000,  1488,   250,  1394,   400,    79,    84,   272,
# ...

# %% [markdown]
# Analysis of column “Description”

# %%
#cheack the unique values
df["Description"].unique()
# Out:
# array(['WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN',
#        'CREAM CUPID HEARTS COAT HANGER', ..., 'lost',
#        'CREAM HANGING HEART T-LIGHT HOLDER',
#        'PAPER CRAFT , LITTLE BIRDIE'], dtype=object)

# %%
df['descrip']=df["Description"].copy()

# %%
df['Description'] = df['Description'].str.replace(r'[^\w\s]', ' ',regex=True)

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART          6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#        InvoiceDate  UnitPrice  CustomerID         Country Invoice_copy  \
# ...

# %%
df.loc[120:]
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 120       536381    37444A  YELLOW BREAKFAST CUP AND SAUCER         1
# 121       536381    37444C   PINK BREAKFAST CUP AND SAUCER          1
# 122       536381     22086  PAPER CHAIN KIT 50 S CHRISTMAS          4
# 123       536381     22083        PAPER CHAIN KIT RETROSPOT         1
# 124       536381    84971S        SMALL HEART FLOWERS HOOK          6
# ...          ...       ...                              ...       ...
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#        InvoiceDate  UnitPrice  CustomerID         Country Invoice_copy  \
# ...

# %%
df[df['Description'].isnull()]
# Out:
#        InvoiceNo StockCode Description  Quantity InvoiceDate  UnitPrice  \
# 622       536414     22139         NaN        56  2010-12-01        0.0
# 1970      536545     21134         NaN         1  2010-12-01        0.0
# 1971      536546     22145         NaN         1  2010-12-01        0.0
# 1972      536547     37509         NaN         1  2010-12-01        0.0
# 1987      536549    85226A         NaN         1  2010-12-01        0.0
# ...          ...       ...         ...       ...         ...        ...
# 535322    581199     84581         NaN         0  2011-12-07        0.0
# 535326    581203     23406         NaN        15  2011-12-07        0.0
# 535332    581209     21620         NaN         6  2011-12-07        0.0
# 536981    581234     72817         NaN        27  2011-12-08        0.0
# 538554    581408     85175         NaN        20  2011-12-08        0.0
#
#         CustomerID         Country Invoice_copy descrip
# ...

# %%
#replacing Nan value with ' '[whitespace]
df["Description"].fillna(" ",inplace=True)

# %%
#again cheack nan values 
df["Description"].isnull().sum()
# Out:
# 0

# %% [markdown]
# # Cheack the null values in whole dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   InvoiceNo     541909 non-null  object
#  1   StockCode     541909 non-null  object
#  2   Description   541909 non-null  object
#  3   Quantity      541909 non-null  int64
#  4   InvoiceDate   541909 non-null  object
#  5   UnitPrice     541909 non-null  float64
#  6   CustomerID    541909 non-null  float64
#  7   Country       541909 non-null  object
#  8   Invoice_copy  541909 non-null  object
#  9   descrip       540455 non-null  object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 41.3+ MB

# %%
data.isnull().sum()
# Out:
# InvoiceNo          0
# StockCode          0
# Description        0
# Quantity           0
# InvoiceDate        0
# UnitPrice          0
# CustomerID         0
# Country            0
# Invoice_copy       0
# Date_copy          0
# descrip         1454
# dtype: int64
